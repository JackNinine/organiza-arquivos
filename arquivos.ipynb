png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-03-12 143129.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-03-12 155731.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-03-12 165816.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-03-13 093646.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-03-23 102415.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-03-25 134733.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-03-31 103027.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-03-31 103950.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-03-31 103959.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-04-19 211938.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-04-26 195510.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-04-26 195519.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-05-05 170626.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-05-24 200153.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-07-02 164211.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-07-02 164651.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-07-05 195508.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-07-10 120557.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-07-10 121524.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-07-10 182343.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-07-24 105456.png movido para a pasta IMAGES.
# Arquivo Captura de tela 2026-07-24 105504.png movido para a pasta IMAGES.
# Arquivo cep.csv movido para a pasta CSV.
# Arquivo cep.txt movido para a pasta TXT.
# Arquivo Contoso - Cadastro Produtos.csv movido para a pasta CSV.
# Arquivo Contoso - Vendas - 2017.csv movido para a pasta CSV.
# Arquivo contoso_cadastro_Econômico.csv movido para a pasta CSV.
# Arquivo contoso_cadastro_Luxo.csv movido para a pasta CSV.
# Arquivo contoso_cadastro_Regular.csv movido para a pasta CSV.
# Arquivo images não é suportado e não será movido.
# Arquivo Integração Python e PDF - Como funciona - MGLU_ER_3T20_POR.pdf movido para a pasta PDF.
# Arquivo Lendo Arquivos txt - Alunos.txt movido para a pasta TXT.
# Arquivo MAPA - ANÁLISE PREDITIVA E CLASSIFICAÇÃO - 53_2026.pdf movido para a pasta PDF.
# Arquivo MAPA - IA - COMPUTAÇÃO COGNITIVA - 52_2026.pdf movido para a pasta PDF.
# Arquivo MAPA - IA - INTELIGÊNCIA ARTIFICIAL SIMBÓLICA - 53_2025 - JAQUELINE.pdf movido para a pasta PDF.
# Arquivo MAPA - IA - PROCESSAMENTO DE IMAGENS E VISÃO COMPUTACIONAL - 54_2025 - JAQUELINE.pdf movido para a pasta PDF.
# Arquivo MAPA - IA - REDES NEURAIS GENERATIVAS - 52_2026.pdf movido para a pasta PDF.
# Arquivo MAPA - IA - SISTEMAS ESPECIALISTAS - 53_2025.pdf movido para a pasta PDF.
# Arquivo MAPA - MENTALIDADE CRIATIVA E EMPREENDEDORA - 51_2026.pdf movido para a pasta PDF.
# Arquivo MAPA - TÉCNICAS DE MACHINE LEARNING - 51_2026.pdf movido para a pasta PDF.
# Arquivo PORTFOLIO-IA-IMERSAO PROFISSIONAL RECONHECIMENTO DE PADROES - 54_2025.pdf movido para a pasta PDF.
# Arquivo PORTFÓLIO - IA - IMERSÃO PROFISSIONAL SISTEMAS ESPECIALISTAS E SUAS CATEGORIAS - 53_2025 - JAQUELINE.pdf movido para a pasta PDF.
# Arquivo PORTFÓLIO - IA - IMERSÃO PROFISSIONAL- IA GENERATIVA E TENDÊNCIAS - 52_2026.pdf movido para a pasta PDF.
# Arquivo print_rapido.png movido para a pasta IMAGES.
# Arquivo senha.txt movido para a pasta TXT.
